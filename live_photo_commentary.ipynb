# %%
# %load_ext autoreload
# %autoreload 3

# %%
from live_photo_commentary.synthesizer import Synthesizer
synthesizer = Synthesizer()
# Out:
# /home/matt/.pyenv/versions/phi4/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /home/matt/.pyenv/versions/phi4/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
from live_photo_commentary.describer import Describer
# describer = Describer(local=True, model_id="dummy", max_sentences=4, max_history_size=5)
prompt = (
    "You are a friendly chatty commentator who likes to casually describe work done by a photographer " 
    "in various details, even by pondering the implications on work, or leisure, being performed, etc. "
    "Write your response in a very personal way using personal pronouns and explaining what you see. "
    "Keep the description within two sentences. " 
    "Do your best to not be repetitive in your choice of words. You MUST keep the response length to no more than three sentences. "
    "You MUST NOT mention any specific layout elements or tools that may be visible on the screen, such as gridlines or sliders. "
)
describer = Describer(system_prompt=prompt, local=False, provider="gemini", model_id="gemini-3.1-flash-lite", max_history_size=5, api_key="AIzaSyA8HoI_yiT_aPvCpeoy_MhAMrqHkVGIJmI")
# describer = Describer(local=True, model_id="microsoft/Phi-3.5-vision-instruct", max_history_size=5)
# describer = Describer(local=True, model_id="apple/FastVLM-0.5B", max_history_size=0)
# describer = Describer(local=True, model_id="google/gemma-3-4b-it", max_history_size=0)

# %%
from live_photo_commentary.notebook import UI
# ui = UI(describer, synthesizer, logdir='logs', extra_delay=2)
# ui = UI(describer, synthesizer, logdir='logs', extra_delay=5,
        # screenshot_kwargs=dict(bbox=(185,125,1440,965)), difference_threshold=0.0003)

ui = UI(describer, synthesizer, logdir='logs', extra_delay=1, screenshot_kwargs=dict(bbox=(20,160,3380,2020)), difference_threshold=0.0003)
# Out:
# ...
# HTML(value='')
# Output()
